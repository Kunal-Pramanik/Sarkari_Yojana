# %%
import pandas as pd
# Out:
# c:\Users\Dell\anaconda3\Lib\site-packages\pandas\core\computation\expressions.py:22: UserWarning: Pandas requires version '2.10.2' or newer of 'numexpr' (version '2.10.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_csv('myscheme_cleaned.csv')

# %%
df.head()
# Out:
#                                          Scheme Name Short Title  \
# 0                                  Skill Loan Scheme          SL
# 1  National Overseas Scholarship For Students Wit...     NOS-SWD
# 2  Post Matric Scholarship Students With Disabili...    POST-DIS
# 3  RMEWF-Financial Assistance For Medical Treatme...       RMEWF
# 4                                     Stand-Up India        SUPI
#
#                                             Category    Level    State  \
# 0  ['Skills & Employment', 'Banking,Financial Ser...  Central  ['All']
# 1  ['Education & Learning', 'Social welfare & Emp...  Central  ['All']
# 2  ['Education & Learning', 'Social welfare & Emp...  Central  ['All']
# 3                              ['Health & Wellness']  Central  ['All']
# 4  ['Business & Entrepreneurship', 'Banking,Finan...  Central  ['All']
#
#                                       Nodal Ministry  Priority  \
# 0  Ministry Of Skill Development And Entrepreneur...       1.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4644 entries, 0 to 4643
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Scheme Name           4644 non-null   str
#  1   Short Title           4644 non-null   str
#  2   Category              4644 non-null   str
#  3   Level                 4644 non-null   str
#  4   State                 4644 non-null   str
#  5   Nodal Ministry        633 non-null    str
#  6   Priority              4602 non-null   float64
#  7   Details               4644 non-null   str
#  8   Benefits              4644 non-null   str
#  9   Eligibility Criteria  4644 non-null   str
#  10  Application Process   4644 non-null   str
#  11  combined_text         4644 non-null   str
# dtypes: float64(1), str(11)
# memory usage: 18.9 MB
